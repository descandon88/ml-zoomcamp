# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

# %%
data = 'https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-03-churn-prediction/WA_Fn-UseC_-Telco-Customer-Churn.csv'

# %% [markdown]
# ### 6.2 Data cleaning and preparation

# %% [markdown]
# #### - Downloading the dataset
# #### - Re-encoding the categorical variables
# #### - Doing the train/validation/test split

# %%
data = 'https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-06-trees/CreditScoring.csv'

# %%
# !wget $data
# Out:
# --2025-11-09 19:18:54--  https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-06-trees/CreditScoring.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 182489 (178K) [text/plain]
# Saving to: ‘CreditScoring.csv.3’
#
# CreditScoring.csv.3 100%[===================>] 178.21K  --.-KB/s    in 0.05s
#
# 2025-11-09 19:18:54 (3.41 MB/s) - ‘CreditScoring.csv.3’ saved [182489/182489]

# %%
# !head CreditScoring.csv
# Out:
# "Status","Seniority","Home","Time","Age","Marital","Records","Job","Expenses","Income","Assets","Debt","Amount","Price"
# 1,9,1,60,30,2,1,3,73,129,0,0,800,846
# 1,17,1,60,58,3,1,1,48,131,0,0,1000,1658
# 2,10,2,36,46,2,2,3,90,200,3000,0,2000,2985
# 1,0,1,60,24,1,1,1,63,182,2500,0,900,1325
# 1,0,1,36,26,1,1,1,46,107,0,0,310,910
# 1,1,2,60,36,2,1,1,75,214,3500,0,650,1645
# 1,29,2,60,44,2,1,1,75,125,10000,0,1600,1800
# 1,9,5,12,27,1,1,1,35,80,0,0,200,1093
# 1,0,2,60,32,2,1,3,90,107,15000,0,1200,1957

# %%
df = pd.read_csv(data)
df.head()
# Out:
#    Status  Seniority  Home  Time  Age  Marital  Records  Job  Expenses  \
# 0       1          9     1    60   30        2        1    3        73
# 1       1         17     1    60   58        3        1    1        48
# 2       2         10     2    36   46        2        2    3        90
# 3       1          0     1    60   24        1        1    1        63
# 4       1          0     1    36   26        1        1    1        46
#
#    Income  Assets  Debt  Amount  Price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4455 entries, 0 to 4454
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Status     4455 non-null   int64
#  1   Seniority  4455 non-null   int64
#  2   Home       4455 non-null   int64
#  3   Time       4455 non-null   int64
#  4   Age        4455 non-null   int64
#  5   Marital    4455 non-null   int64
#  6   Records    4455 non-null   int64
#  7   Job        4455 non-null   int64
#  8   Expenses   4455 non-null   int64
#  9   Income     4455 non-null   int64
#  10  Assets     4455 non-null   int64
#  11  Debt       4455 non-null   int64
#  12  Amount     4455 non-null   int64
#  13  Price      4455 non-null   int64
# dtypes: int64(14)
# memory usage: 487.4 KB

# %%
df.columns = df.columns.str.lower()

# %%
df.status.value_counts()
# Out:
# status
# 1    3200
# 2    1254
# 0       1
# Name: count, dtype: int64

# %%
status_values = {1:"ok", 2:"default", 3:"unk"}

df.status = df.status.map(status_values)

# %%
df.head()
# Out:
#     status  seniority  home  time  age  marital  records  job  expenses  \
# 0       ok          9     1    60   30        2        1    3        73
# 1       ok         17     1    60   58        3        1    1        48
# 2  default         10     2    36   46        2        2    3        90
# 3       ok          0     1    60   24        1        1    1        63
# 4       ok          0     1    36   26        1        1    1        46
#
#    income  assets  debt  amount  price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
df.describe()
# Out:
#          seniority         home         time          age      marital  \
# count  4455.000000  4455.000000  4455.000000  4455.000000  4455.000000
# mean      7.987205     2.657015    46.441751    37.077666     1.879012
# std       8.173444     1.610467    14.655225    10.984856     0.643748
# min       0.000000     0.000000     6.000000    18.000000     0.000000
# 25%       2.000000     2.000000    36.000000    28.000000     2.000000
# 50%       5.000000     2.000000    48.000000    36.000000     2.000000
# 75%      12.000000     4.000000    60.000000    45.000000     2.000000
# max      48.000000     6.000000    72.000000    68.000000     5.000000
#
#            records          job     expenses        income        assets  \
# count  4455.000000  4455.000000  4455.000000  4.455000e+03  4.455000e+03
# mean      1.173513     1.675870    55.568799  7.633170e+05  1.060341e+06
# std       0.378733     0.954035    19.515878  8.703625e+06  1.021757e+07
# min       1.000000     0.000000    35.000000  0.000000e+00  0.000000e+00
# 25%       1.000000     1.000000    35.000000  8.000000e+01  0.000000e+00
# 50%       1.000000     1.000000    51.000000  1.200000e+02  3.500000e+03
# 75%       1.000000     3.000000    72.000000  1.660000e+02  6.000000e+03
# max       2.000000     4.000000   180.000000  1.000000e+08  1.000000e+08
#
#                debt       amount         price
# count  4.455000e+03  4455.000000   4455.000000
# mean   4.043820e+05  1039.021773   1462.875645
# std    6.344253e+06   474.543007    628.089913
# min    0.000000e+00   100.000000    105.000000
# 25%    0.000000e+00   700.000000   1117.500000
# 50%    0.000000e+00  1000.000000   1400.000000
# 75%    0.000000e+00  1300.000000   1692.000000
# max    1.000000e+08  5000.000000  11140.000000

# %%
df.describe().round(2)
# Out:
#        seniority     home     time      age  marital  records      job  \
# count    4455.00  4455.00  4455.00  4455.00  4455.00  4455.00  4455.00
# mean        7.99     2.66    46.44    37.08     1.88     1.17     1.68
# std         8.17     1.61    14.66    10.98     0.64     0.38     0.95
# min         0.00     0.00     6.00    18.00     0.00     1.00     0.00
# 25%         2.00     2.00    36.00    28.00     2.00     1.00     1.00
# 50%         5.00     2.00    48.00    36.00     2.00     1.00     1.00
# 75%        12.00     4.00    60.00    45.00     2.00     1.00     3.00
# max        48.00     6.00    72.00    68.00     5.00     2.00     4.00
#
#        expenses       income       assets         debt   amount     price
# count   4455.00      4455.00      4455.00      4455.00  4455.00   4455.00
# mean      55.57    763316.99   1060340.81    404381.96  1039.02   1462.88
# std       19.52   8703625.26  10217568.67   6344253.40   474.54    628.09
# min       35.00         0.00         0.00         0.00   100.00    105.00
# 25%       35.00        80.00         0.00         0.00   700.00   1117.50
# 50%       51.00       120.00      3500.00         0.00  1000.00   1400.00
# 75%       72.00       166.00      6000.00         0.00  1300.00   1692.00
# max      180.00  99999999.00  99999999.00  99999999.00  5000.00  11140.00

# %%
for c in ["income", "assets", "debt"]:
    df[c] = df[c].replace(to_replace=999999,value=np.nan)
#df.income.replace(to_replace=999999,value=np.nan).max()

# %%
df.describe().round()
# Out:
#        seniority    home    time     age  marital  records     job  expenses  \
# count     4455.0  4455.0  4455.0  4455.0   4455.0   4455.0  4455.0    4455.0
# mean         8.0     3.0    46.0    37.0      2.0      1.0     2.0      56.0
# std          8.0     2.0    15.0    11.0      1.0      0.0     1.0      20.0
# min          0.0     0.0     6.0    18.0      0.0      1.0     0.0      35.0
# 25%          2.0     2.0    36.0    28.0      2.0      1.0     1.0      35.0
# 50%          5.0     2.0    48.0    36.0      2.0      1.0     1.0      51.0
# 75%         12.0     4.0    60.0    45.0      2.0      1.0     3.0      72.0
# max         48.0     6.0    72.0    68.0      5.0      2.0     4.0     180.0
#
#            income      assets        debt  amount    price
# count      4455.0      4455.0      4455.0  4455.0   4455.0
# mean     763317.0   1060341.0    404382.0  1039.0   1463.0
# std     8703625.0  10217569.0   6344253.0   475.0    628.0
# min           0.0         0.0         0.0   100.0    105.0
# 25%          80.0         0.0         0.0   700.0   1118.0
# 50%         120.0      3500.0         0.0  1000.0   1400.0
# 75%         166.0      6000.0         0.0  1300.0   1692.0
# max    99999999.0  99999999.0  99999999.0  5000.0  11140.0

# %%
df.status.value_counts()
# Out:
# status
# ok         3200
# default    1254
# Name: count, dtype: int64

# %%
df = df[df.status != 'unk'].reset_index(drop=True)
df.head()
# Out:
#     status  seniority  home  time  age  marital  records  job  expenses  \
# 0       ok          9     1    60   30        2        1    3        73
# 1       ok         17     1    60   58        3        1    1        48
# 2  default         10     2    36   46        2        2    3        90
# 3       ok          0     1    60   24        1        1    1        63
# 4       ok          0     1    36   26        1        1    1        46
#
#    income  assets  debt  amount  price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
from sklearn.model_selection import train_test_split

df_full_train, df_test = train_test_split(df, test_size=0.2, random_state =11)

df_train, df_val = train_test_split(df_full_train,test_size=0.25, random_state = 11)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = (df_train.status == 'default').astype('int').values
y_val = (df_val.status == 'default').astype('int').values
y_test = (df_test.status == 'default').astype('int').values

# %%
del df_train['status']
del df_val['status']
del df_test['status']

# %%
df_train
# Out:
#       seniority  home  time  age  marital  records  job  expenses  income  \
# 0             3     1    36   61        2        1    1        41      57
# 1             5     1    48   30        4        2    2        39      41
# 2            15     2    60   32        5        1    3        35       0
# 3             2     1    12   47        2        2    1       103     426
# 4             6     5    48   32        1        2    1        35      85
# ...         ...   ...   ...  ...      ...      ...  ...       ...     ...
# 2668          1     5    60   21        1        1    2        35      45
# 2669          5     1    60   47        1        2    1        46     106
# 2670         23     1    24   47        1        1    1        44      86
# 2671          5     2    60   58        2        1    3        45      93
# 2672          4     2    48   22        2        1    1        35     214
#
#       assets  debt  amount  price
# 0      12000     0    2500   3559
# 1          0     0    1300   1600
# 2       6000  3300    1550   1612
# 3          0     0     350    450
# 4          0     0    1100   1330
# ...      ...   ...     ...    ...
# 2668       0     0     400    904
# 2669    8500     0    2500   2664
# 2670       0     0     350    975
# 2671   45000     0    1500   2090
# 2672   10000  3000    1250   1566
#
# [2673 rows x 13 columns]

# %% [markdown]
# ### 6.3 Decision trees

# %%
def assess_risk(client):
    if client['records'] == 'yes':
        if client['job'] == 'partime':
            return 'default'
        else:
            return 'ok'
    else:
        if client['assets'] > 6000:
            return 'ok'
        else:
            return 'default'

# %%
xi = df_train.iloc[0].to_dict()
xi
# Out:
# {'seniority': 3,
#  'home': 1,
#  'time': 36,
#  'age': 61,
#  'marital': 2,
#  'records': 1,
#  'job': 1,
#  'expenses': 41,
#  'income': 57,
#  'assets': 12000,
#  'debt': 0,
#  'amount': 2500,
#  'price': 3559}

# %%
assess_risk(xi)
# Out:
# 'ok'

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import roc_auc_score

# %%
from sklearn.feature_extraction import DictVectorizer
v = DictVectorizer(sparse=False)
D = [{'foo': 1, 'bar': 2}, {'foo': 3, 'baz': 1}]
X = v.fit_transform(D)
X
#v.inverse_transform(X) == [{'bar': 2.0, 'foo': 1.0},
#                           {'baz': 1.0, 'foo': 3.0}]
#v.transform({'foo': 4, 'unseen_feature': 3})
# Out:
# array([[2., 0., 1.],
#        [0., 1., 3.]])

# %%
train_dicts = df_train.to_dict(orient='records')
#print(train_dicts)

# %%
dv = DictVectorizer(sparse = False)
X_train = dv.fit_transform(train_dicts)
X_train
# Out:
# array([[6.10e+01, 2.50e+03, 1.20e+04, ..., 1.00e+00, 3.00e+00, 3.60e+01],
#        [3.00e+01, 1.30e+03, 0.00e+00, ..., 2.00e+00, 5.00e+00, 4.80e+01],
#        [3.20e+01, 1.55e+03, 6.00e+03, ..., 1.00e+00, 1.50e+01, 6.00e+01],
#        ...,
#        [4.70e+01, 3.50e+02, 0.00e+00, ..., 1.00e+00, 2.30e+01, 2.40e+01],
#        [5.80e+01, 1.50e+03, 4.50e+04, ..., 1.00e+00, 5.00e+00, 6.00e+01],
#        [2.20e+01, 1.25e+03, 1.00e+04, ..., 1.00e+00, 4.00e+00, 4.80e+01]],
#       shape=(2673, 13))

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train , y_train)
# Out:
# DecisionTreeClassifier()

# %%
val_dicts = df_val.fillna(0).to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
#y_pred = dt.predict_proba(X_val)[:,1]
y_pred = dt.predict_proba(X_train)[:,1]
roc_auc_score(y_train,y_pred)
# Out:
# 1.0

# %%
roc_auc_score(y_val, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 roc_auc_score(y_val, y_pred)
#
# File /opt/conda/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_ranking.py:686, in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     684     labels = np.unique(y_true)
#     685     y_true = label_binarize(y_true, classes=labels)[:, 0]
# --> 686     return _average_binary_score(
#     687         partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     688         y_true,
#     689         y_score,
#     690         average,
#     691         sample_weight=sample_weight,
#     692     )
#     693 else:  # multilabel-indicator
#     694     return _average_binary_score(
#     695         partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     696         y_true,
#    (...)
#     699         sample_weight=sample_weight,
#     700     )
#
# File /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_base.py:69, in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      66     raise ValueError("{0} format is not supported".format(y_type))
#      68 if y_type == "binary":
# ---> 69     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      71 check_consistent_length(y_true, y_score, sample_weight)
#      72 y_true = check_array(y_true)
#
# File /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_ranking.py:433, in _binary_roc_auc_score(y_true, y_score, sample_weight, max_fpr)
#     424     warnings.warn(
#     425         (
#     426             "Only one class is present in y_true. ROC AUC score "
#    (...)
#     429         UndefinedMetricWarning,
#     430     )
#     431     return np.nan
# --> 433 fpr, tpr, _ = roc_curve(y_true, y_score, sample_weight=sample_weight)
#     434 if max_fpr is None or max_fpr == 1:
#     435     return auc(fpr, tpr)
#
# File /opt/conda/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_ranking.py:1163, in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#    1059 @validate_params(
#    1060     {
#    1061         "y_true": ["array-like"],
#    (...)
#    1070     y_true, y_score, *, pos_label=None, sample_weight=None, drop_intermediate=True
#    1071 ):
#    1072     """Compute Receiver operating characteristic (ROC).
#    1073
#    1074     Note: this implementation is restricted to the binary classification task.
#    (...)
#    1161     array([ inf, 0.8 , 0.4 , 0.35, 0.1 ])
#    1162     """
# -> 1163     fps, tps, thresholds = _binary_clf_curve(
#    1164         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#    1165     )
#    1167     # Attempt to drop thresholds corresponding to points in between and
#    1168     # collinear with other points. These are always suboptimal and do not
#    1169     # appear on a plotted ROC curve (and thus do not affect the AUC).
#    (...)
#    1174     # but does not drop more complicated cases like fps = [1, 3, 7],
#    1175     # tps = [1, 2, 4]; there is no harm in keeping too many thresholds.
#    1176     if drop_intermediate and len(fps) > 2:
#
# File /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_ranking.py:865, in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     862 if not (y_type == "binary" or (y_type == "multiclass" and pos_label is not None)):
#     863     raise ValueError("{0} format is not supported".format(y_type))
# --> 865 check_consistent_length(y_true, y_score, sample_weight)
#     866 y_true = column_or_1d(y_true)
#     867 y_score = column_or_1d(y_score)
#
# File /opt/conda/lib/python3.11/site-packages/sklearn/utils/validation.py:473, in check_consistent_length(*arrays)
#     471 lengths = [_num_samples(X) for X in arrays if X is not None]
#     472 if len(set(lengths)) > 1:
# --> 473     raise ValueError(
#     474         "Found input variables with inconsistent numbers of samples: %r"
#     475         % [int(l) for l in lengths]
#     476     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [891, 2673]

# %%
## https://www.youtube.com/watch?v=YGiQvFbSIg8&list=PL3MmuxUbc_hIhxl5Ji8t4O6lPAOpHaCLR&index=62
## minute 10:26

# %%
#### Changing the model defining the depth
dt = DecisionTreeClassifier(max_depth=2)
dt.fit(X_train,y_train)

#y_pred = dt.predict_proba(X_val)[:,1]
#roc_auc_score(y_val,y_pred)

y_pred = dt.predict_proba(X_train)[:,1]
auc = roc_auc_score(y_train, y_pred)
print('train:', auc)

y_pred = dt.predict_proba(X_val)[:,1]
auc = roc_auc_score(y_val, y_pred)
print('val:', auc)
# Out:
# train: 0.7228170289982685
# val: 0.6895511687412701

# %%
from sklearn.tree import export_text
#print(export_text(dt, feature_names = dv.get_feature_names()))
print(export_text(dt, feature_names=dv.get_feature_names_out()))
# Out:
# |--- records <= 1.50
# |   |--- seniority <= 2.50
# |   |   |--- class: 0
# |   |--- seniority >  2.50
# |   |   |--- class: 0
# |--- records >  1.50
# |   |--- seniority <= 6.50
# |   |   |--- class: 1
# |   |--- seniority >  6.50
# |   |   |--- class: 0

# %% [markdown]
# ### 6.4 Decision tree learning algorithm

# %% [markdown]
# #### - Fiding the best split for one column
# #### - Finding the best split for the entire dataset
# #### - Stopping criteria

# %%
data = [ 
    [8000, 'default'],
    [2000, 'default'],
    [0 , 'default'],
    [5000, 'ok'],
    [4000, 'ok'],
    [9000, 'ok'],
    [3000, 'default'],
]

df_example = pd.DataFrame(data, columns=['assets','status'])
df_example.head()
# Out:
#    assets   status
# 0    8000  default
# 1    2000  default
# 2       0  default
# 3    5000       ok
# 4    4000       ok

# %%
df_example.sort_values('assets')
# Out:
#    assets   status
# 2       0  default
# 1    2000  default
# 6    3000  default
# 4    4000       ok
# 3    5000       ok
# 0    8000  default
# 5    9000       ok

# %%
Ts = [2000, 3000 , 4000 ,   5000 , 8000 , 9000]

# %%
for t in Ts:
    df_left = df_example[df_example.assets <= t]
    df_right = df_example[df_example.assets > t]
    display(df_left)
    display(df_right)
    print()
# Out:
#    assets   status
# 1    2000  default
# 2       0  default
#    assets   status
# 0    8000  default
# 3    5000       ok
# 4    4000       ok
# 5    9000       ok
# 6    3000  default
#    assets   status
# 1    2000  default
# 2       0  default
# 6    3000  default
#    assets   status
# 0    8000  default
# 3    5000       ok
# 4    4000       ok
# 5    9000       ok
#    assets   status
# 1    2000  default
# 2       0  default
# 4    4000       ok
# 6    3000  default
#    assets   status
# 0    8000  default
# 3    5000       ok
# 5    9000       ok
#    assets   status
# 1    2000  default
# 2       0  default
# 3    5000       ok
# 4    4000       ok
# 6    3000  default
#    assets   status
# 0    8000  default
# 5    9000       ok
#    assets   status
# 0    8000  default
# 1    2000  default
# 2       0  default
# 3    5000       ok
# 4    4000       ok
# 6    3000  default
#    assets status
# 5    9000     ok
#    assets   status
# 0    8000  default
# 1    2000  default
# 2       0  default
# 3    5000       ok
# 4    4000       ok
# 5    9000       ok
# 6    3000  default
# Empty DataFrame
# Columns: [assets, status]
# Index: []
